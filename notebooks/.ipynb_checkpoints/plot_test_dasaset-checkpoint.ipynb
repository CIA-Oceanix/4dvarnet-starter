# %%
pip install hvplot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 KB 2.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 33.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 KB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.3/260.3 KB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 33.5 MB/s eta 0:00:0000:01:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 23.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 KB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.4/435.4 KB 25.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 KB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 KB 5.6 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import xarray as xr
import hvplot.xarray
import holoviews as hv
import matplotlib.pyplot as plt

# %%
output_path = '/homes/g24meda/lab/4dvarnet-starter/outputs/2024-05-14/13-23-38/base/test_data.nc'

# %%
test_out = xr.open_dataset(output_path)
test_out
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 81, lat: 240, lon: 240)
# Coordinates:
#   * time     (time) datetime64[ns] 2012-10-01T12:00:00 ... 2012-12-20T12:00:00
#   * lat      (lat) float64 32.0 32.05 32.1 32.15 32.2 ... 43.8 43.85 43.9 43.95
#   * lon      (lon) float64 -65.95 -65.9 -65.85 -65.8 ... -54.1 -54.05 -54.0
# Data variables:
#     inp      (time, lat, lon) float64 ...
#     tgt      (time, lat, lon) float64 ...
#     out      (time, lat, lon) float64 ...

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plotting each subplot
test_out.out.isel(time=10).plot(ax=axs[0])
test_out.tgt.isel(time=10).plot(ax=axs[1])
test_out.inp.isel(time=10).plot(ax=axs[2])

plt.show()
